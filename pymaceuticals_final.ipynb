# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The number of males and females is nearly equal, which helps to avoid unfairness. Capomulin and Ramicane are more effective in reducing tumor size compared to Infubinol and Ceftamin. In the Capomulin treatment, heavier mice usually have bigger tumors, as shown by a 0.84 correlation between weight and tumor size.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combine_data = pd.merge(study_results, mouse_metadata, on='Mouse ID')

# Display the data table for preview
combine_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice.
mice_number = combine_data ['Mouse ID'].nunique()
mice_number
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combine_data[combine_data.duplicated(subset=['Mouse ID','Timepoint'])]['Mouse ID'].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_id = combine_data[combine_data.duplicated(subset=['Mouse ID','Timepoint'],keep=False)]
duplicate_id
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
duplicate_drop = combine_data[combine_data['Mouse ID']!= 'g989']

# %%
# Checking the number of mice in the clean DataFrame.
clean_data = duplicate_drop['Mouse ID'].nunique()
clean_data
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
group = duplicate_drop.groupby('Drug Regimen')
group_mean = group ['Tumor Volume (mm3)'].mean()
group_median = group ['Tumor Volume (mm3)'].median()
group_variance = group ['Tumor Volume (mm3)'].var()
group_std = group ['Tumor Volume (mm3)'].std()
group_sem = group ['Tumor Volume (mm3)'].sem()

summary = pd.DataFrame({
            "Tumor Volume Mean" : group_mean,
            "Tumor Volume Median" : group_median,
            "Tumor Volume Variance" : group_variance,
            "Tumor Volume Standard Deviation" : group_std,
            "Tumor Volume SEM" : group_sem})
summary
# Out:
#               Tumor Volume Mean  Tumor Volume Median  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  Tumor Volume SEM
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_aggregation = group['Tumor Volume (mm3)'].agg(['mean','median','var','std','sem'])
summary_aggregation
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug = group.size()
drug.plot(kind="bar")
plt.ylabel("Number of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
pyplot = group.size()
pyplot.index
plt.bar(pyplot.index,pyplot)
plt.xticks(rotation=90)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Observed Mouse Timepoints')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_gender = duplicate_drop['Sex'].value_counts()
mice_gender.plot(kind='pie',autopct = '%1.1f%%')
plt.ylabel('Sex')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(mice_gender,labels=mice_gender.index,autopct = '%1.1f%%')
plt.ylabel('gender')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
combine_4=duplicate_drop[(duplicate_drop['Drug Regimen']=='Capomulin')|
                         (duplicate_drop['Drug Regimen']=='Ramicane')|
                         (duplicate_drop['Drug Regimen']=='Infubinol')|
                         (duplicate_drop['Drug Regimen']=='Ceftamin')]
# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = combine_4.groupby('Mouse ID')['Timepoint'].max()
last_timepoint = last_timepoint.reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merge=pd.merge(combine_4,last_timepoint,on=['Mouse ID','Timepoint'])
merge
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      b128         45           38.982878                 2    Capomulin
# 1      c326          5           36.321346                 0    Infubinol
# 2      c139         45           72.226731                 2    Infubinol
# 3      v339          5           46.250112                 0    Infubinol
# 4      a577         30           57.031862                 2    Infubinol
# ..      ...        ...                 ...               ...          ...
# 95     t565         45           34.455298                 0    Capomulin
# 96     i557         45           47.685963                 1    Capomulin
# 97     m957         45           33.329098                 1    Capomulin
# 98     f966         20           30.485985                 0    Capomulin
# 99     m601         45           28.430964                 1    Capomulin
#
#        Sex  Age_months  Weight (g)
# 0   Female           9          22
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
ramicane =[
    'Capomulin', 
    'Ramicane', 
    'Infubinol', 
    'Ceftamin']
tumor =[]

for drug in ramicane:
    tumor_final=merge[merge['Drug Regimen']==drug]['Tumor Volume (mm3)']
    tumor.append(tumor_final)
    quartiles = tumor_final.quantile([.25,.5,.75])
    lowerq = quartiles[.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers= tumor_final[(tumor_final>upper_bound) | (tumor_final<lower_bound) ]
    print(f"{drug}'s  potential outliers: {outliers}")

# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's  potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's  potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's  potential outliers: 1    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's  potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volume')
bp = ax1.boxplot(tumor,labels=ramicane)
plt.setp(bp['fliers'], linewidth=2.0)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
Capomulin=duplicate_drop[duplicate_drop['Drug Regimen']=='Capomulin']
CapomulinMice=Capomulin['Mouse ID'].unique()
number = 9
CapomulinMouse=Capomulin[Capomulin['Mouse ID']==CapomulinMice[number]]
plt.plot(CapomulinMouse['Timepoint'],CapomulinMouse['Tumor Volume (mm3)'])
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume')
plt.title(f'Capomulin treatment of mouse {CapomulinMice[number]}')

plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
weight = Capomulin.groupby('Mouse ID')['Weight (g)'].mean()
volume = Capomulin.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()
plt.scatter(weight,volume)
plt.title('Mouse Weight vs. Average Tumor Volume')
plt.xlabel('Mouse Weight')
plt.ylabel('Average Tumor Volume')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

correlation, p_value = st.pearsonr(weight, volume)
correlation=round(correlation,2)
print({correlation})

from scipy.stats import linregress

(slope, intercept, rvalue, pvalue, stderr) = linregress(weight, volume)
regress = weight * slope + intercept

plt.scatter(weight,volume)
plt.plot(weight,regress,"r-")

plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# {0.84}
